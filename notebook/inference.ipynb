# %%
import sys
sys.path.insert(0, "../")

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
import seaborn as sns
import pickle

# %%
df_test = pd.read_csv("../dataset/test.csv")
df_test.head()
# Out:
#    id  battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0   1           1043     1          1.8         1  14       0           5
# 1   2            841     1          0.5         1   4       1          61
# 2   3           1807     1          2.8         0   1       0          27
# 3   4           1546     0          0.5         1  18       1          25
# 4   5           1434     0          1.4         0  11       1          49
#
#    m_dep  mobile_wt  ...  pc  px_height  px_width   ram  sc_h  sc_w  \
# 0    0.1        193  ...  16        226      1412  3476    12     7
# 1    0.8        191  ...  12        746       857  3895     6     0
# 2    0.9        186  ...   4       1270      1366  2396    17    10
# 3    0.5         96  ...  20        295      1752  3893    10     0
# 4    0.5        108  ...  18        749       810  1773    15     8
#
#    talk_time  three_g  touch_screen  wifi
# 0          2        0             1     0
# 1          7        1             0     0
# 2         10        0             1     1
# 3          7        1             1     0
# 4          7        1             0     1
#
# [5 rows x 21 columns]

# %%
## splitting the data into independent and dependent features
X = df_test.drop('id',axis=1)
idx = df_test['id']

# %%
model = pickle.load(open("../weights/DecisionTree.pkl", "rb"))

# %%
predictions = model.predict(X)
predictions
# Out:
# array([3, 3, 2, 2, 1, 3, 3, 0, 3, 0, 3, 3, 0, 0, 2, 0, 2, 1, 3, 2, 0, 2,
#        2, 1, 3, 0, 2, 0, 3, 0, 2, 0, 3, 0, 1, 1, 3, 1, 2, 1, 1, 2, 0, 0,
#        0, 0, 1, 3, 1, 2, 1, 1, 2, 0, 3, 1, 3, 1, 1, 3, 3, 3, 0, 1, 1, 1,
#        1, 2, 1, 2, 1, 2, 2, 3, 3, 0, 2, 0, 1, 3, 1, 3, 3, 1, 3, 0, 3, 1,
#        3, 0, 1, 2, 2, 0, 2, 1, 0, 2, 1, 3, 1, 0, 0, 3, 1, 2, 0, 1, 2, 3,
#        3, 2, 1, 3, 2, 3, 3, 2, 3, 0, 0, 3, 1, 1, 2, 0, 3, 2, 3, 1, 0, 2,
#        1, 1, 3, 1, 1, 0, 3, 2, 1, 2, 1, 3, 2, 3, 3, 3, 2, 3, 3, 3, 0, 0,
#        3, 2, 3, 3, 3, 3, 2, 2, 3, 3, 3, 3, 0, 0, 3, 0, 0, 0, 2, 1, 0, 1,
#        1, 0, 1, 3, 1, 0, 0, 1, 1, 2, 2, 1, 0, 0, 0, 0, 1, 3, 2, 1, 2, 2,
#        2, 3, 1, 2, 3, 2, 3, 2, 2, 0, 0, 0, 1, 2, 0, 2, 3, 3, 1, 2, 0, 3,
#        2, 2, 3, 1, 0, 1, 0, 3, 1, 1, 0, 2, 2, 1, 3, 1, 3, 0, 3, 1, 2, 0,
#        0, 2, 1, 3, 3, 3, 2, 1, 3, 0, 0, 2, 3, 3, 1, 3, 1, 1, 3, 2, 1, 2,
#        3, 3, 3, 1, 1, 0, 2, 3, 1, 1, 3, 2, 0, 3, 0, 0, 2, 0, 0, 3, 2, 3,
#        2, 2, 1, 3, 3, 2, 3, 1, 2, 1, 2, 0, 2, 3, 1, 0, 0, 3, 0, 3, 0, 1,
#        2, 0, 2, 3, 1, 3, 2, 2, 1, 2, 0, 0, 0, 1, 3, 1, 0, 0, 0, 3, 2, 0,
#        2, 3, 0, 3, 2, 2, 3, 1, 3, 3, 2, 2, 3, 3, 3, 0, 3, 1, 3, 1, 3, 1,
#        3, 3, 0, 1, 0, 3, 1, 3, 2, 3, 0, 0, 0, 0, 2, 0, 0, 2, 1, 1, 1, 3,
#        2, 0, 1, 0, 0, 3, 2, 1, 3, 1, 1, 2, 1, 2, 3, 1, 1, 3, 2, 1, 2, 0,
